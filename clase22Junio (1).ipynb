# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import pandas
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
#df1.describe(include='all')
#df1.head()
#df1.index = df1[["Plazo"]])
df1 = df1[["Plazo"]]
df1.plot(kind="line")
plt.title('Plazo')
plt.xlabel('Muestra')
plt.ylabel('PLAZO')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import pandas
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
#df1.describe(include='all')
#df1.head()
#df1.index = df1[["Plazo"]])
df1 = df1[["Plazo"]]
# df1[1:11]se grafica para las 10 primeras muestras
df1[1:11].plot(kind="line")
plt.title('Plazo')
plt.xlabel('Muestra')
plt.ylabel('PLAZO')
plt.show()

# %%
# las 50 primeras muestras
df1[1:51].plot(kind="line")
plt.title('Plazo')
plt.xlabel('Muestra')
plt.ylabel('PLAZO')
plt.show()

# %%
df1[1:51].plot(kind="line")
plt.title('Tasa')
plt.xlabel('Muestra')
plt.ylabel('Tasa')
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#import pandas
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1 = df1[["Tasa","Plazo"]]
df1[1:51].plot(kind ="line")
plt.title("Tasa y Plazo")
plt.xlabel('Muestra')
plt.ylabel("Tasa y Plazo")
plt.show()

# %%
import numpy as np
X = np.linspace(-10, 10, 50, endpoint= True, dtype = float) #dtype no es necesario
print(X)
# Out:
# [-10.          -9.59183673  -9.18367347  -8.7755102   -8.36734694
#   -7.95918367  -7.55102041  -7.14285714  -6.73469388  -6.32653061
#   -5.91836735  -5.51020408  -5.10204082  -4.69387755  -4.28571429
#   -3.87755102  -3.46938776  -3.06122449  -2.65306122  -2.24489796
#   -1.83673469  -1.42857143  -1.02040816  -0.6122449   -0.20408163
#    0.20408163   0.6122449    1.02040816   1.42857143   1.83673469
#    2.24489796   2.65306122   3.06122449   3.46938776   3.87755102
#    4.28571429   4.69387755   5.10204082   5.51020408   5.91836735
#    6.32653061   6.73469388   7.14285714   7.55102041   7.95918367
#    8.36734694   8.7755102    9.18367347   9.59183673  10.        ]

# %%
import numpy as np
X = np.linspace(-10, 10, 100, endpoint= True, dtype = float) #dtype no es necesario
print(X)
#100 datos
# Out:
# [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...

# %%
import numpy as np
X = np.linspace(-20, 20, 100, endpoint= True, dtype = float) #dtype no es necesario
print(X)
#100 datos entre el 20 y -20 , valores aleatorios
# Out:
# [-20.         -19.5959596  -19.19191919 -18.78787879 -18.38383838
#  -17.97979798 -17.57575758 -17.17171717 -16.76767677 -16.36363636
#  -15.95959596 -15.55555556 -15.15151515 -14.74747475 -14.34343434
#  -13.93939394 -13.53535354 -13.13131313 -12.72727273 -12.32323232
#  -11.91919192 -11.51515152 -11.11111111 -10.70707071 -10.3030303
#   -9.8989899   -9.49494949  -9.09090909  -8.68686869  -8.28282828
#   -7.87878788  -7.47474747  -7.07070707  -6.66666667  -6.26262626
#   -5.85858586  -5.45454545  -5.05050505  -4.64646465  -4.24242424
#   -3.83838384  -3.43434343  -3.03030303  -2.62626263  -2.22222222
#   -1.81818182  -1.41414141  -1.01010101  -0.60606061  -0.2020202
#    0.2020202    0.60606061   1.01010101   1.41414141   1.81818182
#    2.22222222   2.62626263   3.03030303   3.43434343   3.83838384
#    4.24242424   4.64646465   5.05050505   5.45454545   5.85858586
#    6.26262626   6.66666667   7.07070707   7.47474747   7.87878788
# ...

# %%
#graficar el seno y el coseno

import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
#graficar el seno y el coseno

import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
Z = np.cos(X+10)
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, Z)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
#graficar el seno y el coseno

import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
Z = X
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, Z)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
#graficar el seno y el coseno

import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
T = np.cos(X+10)
Z = np.sin(X+15)
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, T)
pl.plot(X, Z)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S = (X+5),(X-5)
T = X+10
Z = X
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, T)
pl.plot(X, Z)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C, S, Z, W, Y = np.cos(X), np.sin(X), np.cos(X-1), np.sin(X-1), 2*X**0 #** es para potencia se multiplica por X para que tome los 256 valores
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, Z)
pl.plot(X, W)
pl.plot(X, Y)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
#cuadrado
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot([0.5, 0.5, 2, 2, 0.5], [0.5, 2, 2, 0.5, 0.5])
plt.show()

# %%
#CUADRADO
import numpy as np
import pylab as pl
X = np.linspace(-np.pi, np.pi , 256, endpoint=True)
C = X*0
S = X
T = X + 20
Z = X + 15
print(X)
pl.plot(X, C)
pl.plot(X, S)
pl.plot(X, T)
pl.plot(X, Z)
pl.show()
# Out:
# [-3.14159265 -3.11695271 -3.09231277 -3.06767283 -3.04303288 -3.01839294
#  -2.993753   -2.96911306 -2.94447311 -2.91983317 -2.89519323 -2.87055329
#  -2.84591335 -2.8212734  -2.79663346 -2.77199352 -2.74735358 -2.72271363
#  -2.69807369 -2.67343375 -2.64879381 -2.62415386 -2.59951392 -2.57487398
#  -2.55023404 -2.52559409 -2.50095415 -2.47631421 -2.45167427 -2.42703432
#  -2.40239438 -2.37775444 -2.3531145  -2.32847456 -2.30383461 -2.27919467
#  -2.25455473 -2.22991479 -2.20527484 -2.1806349  -2.15599496 -2.13135502
#  -2.10671507 -2.08207513 -2.05743519 -2.03279525 -2.0081553  -1.98351536
#  -1.95887542 -1.93423548 -1.90959553 -1.88495559 -1.86031565 -1.83567571
#  -1.81103577 -1.78639582 -1.76175588 -1.73711594 -1.712476   -1.68783605
#  -1.66319611 -1.63855617 -1.61391623 -1.58927628 -1.56463634 -1.5399964
#  -1.51535646 -1.49071651 -1.46607657 -1.44143663 -1.41679669 -1.39215674
#  -1.3675168  -1.34287686 -1.31823692 -1.29359698 -1.26895703 -1.24431709
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
x= df1[["NPS"]]
y= df1[["Plazo"]]
plt.scatter(x,y)
plt.title('Dispersión Tasa Vs Plazo')
plt.xlabel('NPS')
plt.ylabel('Plazo')
plt.show()

# %%
#Histograma
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
df = dp.read_csv('DataPrueba.csv',',',',')
df = df1[["Tasa","Plazo","NPS"]]
count, bin_edges = np.histogram(df['NPS'])
df['NPS'].plot(kind="hist", xticks=bin_edges)
plt.show()

# %%
#Histograma
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
df = dp.read_csv('DataPrueba.csv',',',',')
df = df1[["Tasa","Plazo","NPS"]]
count, bin_edges = np.histogram(df['Plazo'])
df['Plazo'].plot(kind="hist", xticks=bin_edges)
plt.show()

# %%
#Histograma
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
df = dp.read_csv('DataPrueba.csv',',',',')
df = df1[["Tasa","Plazo","NPS"]]
plt.figure(figsize=(8, 6), dpi=80) # se agrego esta linea y la figura aumento de tamaño
count, bin_edges = np.histogram(df['Plazo'])
df['Plazo'].plot(kind="hist", xticks=bin_edges)
plt.show()

# %%
#Histograma
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
df = dp.read_csv('DataPrueba.csv',',',',')
df = df1[["Tasa","Plazo","NPS"]]
plt.figure(figsize=(10, 8), dpi=150) # se agrego esta linea y la figura aumento de tamaño
count, bin_edges = np.histogram(df['Plazo'])
df['Plazo'].plot(kind="hist", xticks=bin_edges)
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df.index
df1.columns
ax1 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=50, c='NPS', cmap='jet') #cmap='viridis'
ax2 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=50, c='NPS', cmap='viridis') #cmap='viridis'
#fig, (ax1,ax2) = plt.subplots(1, 2)
#plt.colorbar()
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df.index
df1.columns
ax1 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=100, c='NPS', cmap='jet') #cmap='viridis' #S cambio en el numero los circulos crecen
ax2 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=50, c='NPS', cmap='viridis') #cmap='viridis'
#fig, (ax1,ax2) = plt.subplots(1, 2)
#plt.colorbar()
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df.index
df1.columns
ax1 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=100, c='NPS', cmap='winter') #cmap='viridis' #S cambio en el numero los circulos crecen
ax2 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=150, c='NPS', cmap='spring') #cmap='viridis'
ax3 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=50, c='NPS', cmap='summer') #cmap='viridis'
#fig, (ax1,ax2,ax3) = plt.subplots(1, 2, 3)
#plt.colorbar()
plt.show()

# %%
#Paso1 - el tamaño de la burbuja depende el tiempo de atención 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df.index
df1.columns
ax1 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s= df1['NPS']*100, c='NPS', cmap='winter') #cmap='viridis' #S cambio en el numero los circulos crecen
ax2 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=150, c='NPS', cmap='spring') #cmap='viridis'
ax3 = df1.plot(kind='scatter',x='Plazo',y='Tasa',s=50, c='NPS', cmap='summer') #cmap='viridis'
#fig, (ax1,ax2,ax3) = plt.subplots(1, 2, 3)
#plt.colorbar()
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df1.index
df1.columns

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='hot', marker='o') #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='winter', marker=(5, 1)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='spring', marker=(5, 2)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='autumn', marker='+') #cmap='viridis', jet, hot, Greens
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df1.index
df1.columns

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='hot', marker='o') #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='winter', marker=(5, 1)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='spring', marker=(5, 2)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='autumn', marker='+') #cmap='viridis', jet, hot, Greens
plt.show()

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
#Paso2
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df1.index
df1.columns

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='hot', marker='o') #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='winter', marker=(5, 1)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='spring', marker=(5, 2)) #cmap='viridis', jet, hot, Greens

df1.plot(kind='scatter',x='Tasa',y='TiempodeAtencion',s=df1['Plazo']*5, c = 'NPS',cmap='autumn', marker='+') #cmap='viridis', jet, hot, Greens
plt.show()
#plt.scatter(x, y, s=80, c=z, marker=">")
#plt.scatter(x, y, s=80, c=z, marker=(5, 0))
#plt.scatter(x, y, s=80, c=z, marker=(5, 1))
#plt.scatter(x, y, s=80, c=z, marker='+')
#plt.scatter(x, y, s=80, c=z, marker=(5, 2)

# %%
#Paso1
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as dp
df1 = dp.read_csv('DataPrueba.csv',',',',')
df1.columns
df1.columns = ['ID', 'TiempodeAtencion', 'TipoAtencion', 'CanalAtencion','Monto', 'Tasa', 'Plazo', 'TipoDesembolso', 'NPS', 'TipoNPS']
df1['index1'] = df.index
df1.columns
df1.hist(figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9e03563710>,
# ...
#       dtype=object)

# %%
#te dice la frecuencia por valor
df1.Plazo.hist()

# %%
df1.Tasa.hist()

# %%
df1.describe()
# Out:
#                   ID  TiempodeAtencion  TipoAtencion        Monto        Tasa  \
# count     125.000000        125.000000    125.000000   125.000000  125.000000
# mean   246707.712000         27.640000      1.472000  3091.080000   23.512000
# std      1586.729782         15.790667      0.501224  1142.356567    7.150024
# min    245851.000000         10.000000      1.000000  1021.000000   12.000000
# 25%    245971.000000         15.000000      1.000000  2180.000000   17.000000
# 50%    246077.000000         20.000000      1.000000  3029.000000   23.000000
# 75%    246218.000000         40.000000      2.000000  4209.000000   30.000000
# max    251653.000000         60.000000      2.000000  4989.000000   36.000000
#
#             Plazo         NPS      index1
# count  125.000000  125.000000  125.000000
# mean    29.440000    7.472000   62.000000
# std     10.650912    1.711328   36.228442
# min     12.000000    5.000000    0.000000
# 25%     19.000000    6.000000   31.000000
# ...

# %%
#los skew deben ser 0 para poder decir que está bien distribuido, un valor de 2 es muy alto
df1.skew()
# Out:
# ID                  2.206884
# TiempodeAtencion    0.623207
# TipoAtencion        0.113543
# Monto              -0.109715
# Tasa                0.057716
# Plazo              -0.047629
# NPS                -0.010412
# index1              0.000000
# dtype: float64

# %%
#ahora veremos las funciones de distribución
#kde= kernell density estination
#distribución empírica rellena los valor vacíos y supone distribucion de fonndo
df1.plot(kind='kde')# pero no se ve

# %%
#saherx no comparten el eje X cada uno a su valor
df1.plot(kind='kde',subplots=True,layout=(2,4),sharex=False,figsize=(11,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9df0425ba8>,
# ...
#       dtype=object)

# %%
lp = np.log(df1.TiempodeAtencion)
# tiempo de tención logaritmico
#graficar los datos como si fuera uno el logaritmo del otro, suavisar tiempo de atencion

# %%
lp
# Out:
# 0      2.944439
# 1      2.995732
# 2      2.890372
# 3      4.007333
# 4      2.995732
#          ...
# 120    2.995732
# 121    2.772589
# 122    3.737670
# 123    2.302585
# 124    2.302585
# Name: TiempodeAtencion, Length: 125, dtype: float64

# %%
lp.plot(kind='kde')

# %%
lp.skew()
# el dataframe ya no es df sino lp
# mide la dispersion de los datos, mas cercano a cero los datos mejor distribuidos
# Out:
# 0.11842141157345076

# %%
λ = -0.6
p_bc = (df1.TiempodeAtencion**λ-1)/λ
p_bc.skew()
# suavisando con lambda para sacar un nuevo skew
# tiempo de atencion elevado al lambda
# Out:
# -0.2282822847867002

# %%
#como saco el lambda,se escribe  \lambda + tab
# λ

# %%
λ = 0.6
p_bc = (df1.TiempodeAtencion**λ-1)/λ
p_bc.skew()
# Out:
# 0.4329120473242959

# %%
λ = -0.2
p_bc = (df1.TiempodeAtencion**λ-1)/λ
p_bc.skew()
#probando los lambda
# Out:
# 0.005809743276131386

# %%
#graficamos los 2 para comparar
p_bc.plot(kind='kde',color='black')
lp.plot(kind='kde', color='blue')

# %%
# usamos es el que tenga el skew mas pegado a cero

# %%
df1.plot(kind='box',subplots=True,layout=(4,2),figsize=(9,7),sharex=False,sharey=False)
# Out:
# ID                      AxesSubplot(0.125,0.71587;0.352273x0.16413)
# TiempodeAtencion     AxesSubplot(0.547727,0.71587;0.352273x0.16413)
# TipoAtencion           AxesSubplot(0.125,0.518913;0.352273x0.16413)
# Monto               AxesSubplot(0.547727,0.518913;0.352273x0.16413)
# Tasa                   AxesSubplot(0.125,0.321957;0.352273x0.16413)
# Plazo               AxesSubplot(0.547727,0.321957;0.352273x0.16413)
# NPS                       AxesSubplot(0.125,0.125;0.352273x0.16413)
# index1                 AxesSubplot(0.547727,0.125;0.352273x0.16413)
# dtype: object

# %%
#veamos la correlación de los datos
df1.corr()
# Out:
#                         ID  TiempodeAtencion  TipoAtencion     Monto  \
# ID                1.000000         -0.139040     -0.087641  0.041120
# TiempodeAtencion -0.139040          1.000000     -0.040513 -0.048745
# TipoAtencion     -0.087641         -0.040513      1.000000 -0.002250
# Monto             0.041120         -0.048745     -0.002250  1.000000
# Tasa             -0.015091         -0.011426      0.042287 -0.156162
# Plazo             0.023806         -0.015306     -0.099641  0.055683
# NPS               0.225888         -0.701541      0.039036  0.073285
# index1           -0.581027          0.152840      0.132791 -0.117516
#
#                       Tasa     Plazo       NPS    index1
# ID               -0.015091  0.023806  0.225888 -0.581027
# TiempodeAtencion -0.011426 -0.015306 -0.701541  0.152840
# TipoAtencion      0.042287 -0.099641  0.039036  0.132791
# Monto            -0.156162  0.055683  0.073285 -0.117516
# Tasa              1.000000 -0.103373  0.036771 -0.000280
# ...

# %%
from matplotlib import pyplot
correlations = df1.corr()
fig=pyplot.figure()
ax=fig.add_subplot(111)
cax=ax.matshow(correlations,vmin=-1,vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,8,1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
names = ['ID', 'TiempodeAtencion', 'TipoAtencion','Monto', 'Tasa', 'Plazo', 'NPS', 'index1']
ax.set_xticklabels(names)
ax.set_yticklabels(names)
# Out:
# [Text(0, 0, 'ID'),
#  Text(0, 0, 'TiempodeAtencion'),
#  Text(0, 0, 'TipoAtencion'),
#  Text(0, 0, 'Monto'),
#  Text(0, 0, 'Tasa'),
#  Text(0, 0, 'Plazo'),
#  Text(0, 0, 'NPS'),
#  Text(0, 0, 'index1')]

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df1,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9df007a320>,
# ...
#       dtype=object)
